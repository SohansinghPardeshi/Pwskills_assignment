# %% [markdown]
# **Q1. What is Bayes' theorem?**
#
# Bayes' theorem, named after Reverend Thomas Bayes, is a mathematical formula that describes the probability of an event based on prior knowledge of conditions that might be related to the event. It is a fundamental concept in probability theory and statistics, particularly in the field of Bayesian statistics. Bayes' theorem is used to update the probability of a hypothesis as more evidence or information becomes available.

# %% [markdown]
# **Q2. What is the formula for Bayes' theorem?**
#
# The formula for Bayes' theorem is:
# ![image.png](attachment:image.png)
#
# **Q3. How is Bayes' theorem used in practice?**
#
# Bayes' theorem is applied in various fields, such as machine learning, medical diagnosis, and information retrieval. In machine learning, particularly in Bayesian statistics, it is used to update the probability of a hypothesis as new data is observed. It provides a framework for incorporating prior knowledge and updating beliefs based on new evidence.
#
# **Q4. What is the relationship between Bayes' theorem and conditional probability?**
#
# Bayes' theorem is essentially a formula that relates conditional probability. It expresses how the probability of an event (A) given some evidence (B) is related to the conditional probability of the evidence given the event and the prior probability of the event. In other words, it formalizes the process of updating probabilities based on new information.
#
# **Q5. How do you choose which type of Naive Bayes classifier to use for any given problem?**
#
# The choice of which type of Naive Bayes classifier to use depends on the nature of the data. The three main types are:
# 1. **Gaussian Naive Bayes:** Suitable for continuous data that follows a normal distribution.
# 2. **Multinomial Naive Bayes:** Typically used for discrete data, such as text data represented as word counts.
# 3. **Bernoulli Naive Bayes:** Appropriate for binary data, where features are either present or absent.
#
# The choice is often guided by the characteristics of the features in your dataset. For example, if your features are continuous, Gaussian Naive Bayes may be appropriate, while for binary data, Bernoulli Naive Bayes might be more suitable.
#
# **Q6. Assignment:**
#
# Given the dataset with features X1 and X2 and classes A and B, and assuming equal prior probabilities for each class, let's calculate the Naive Bayes probabilities for the new instance with features X1 = 3 and X2 = 4.

# %%
# Given data
data = {
    'A': {'X1': [3, 3, 4], 'X2': [4, 3, 3, 3]},
    'B': {'X1': [2, 2, 1], 'X2': [2, 2, 2, 3]}
}

# New instance
new_instance = {'X1': 3, 'X2': 4}

# Calculate likelihoods
likelihood_A = (data['A']['X1'].count(new_instance['X1']) / len(data['A']['X1'])) * \
               (data['A']['X2'].count(new_instance['X2']) / len(data['A']['X2']))

likelihood_B = (data['B']['X1'].count(new_instance['X1']) / len(data['B']['X1'])) * \
               (data['B']['X2'].count(new_instance['X2']) / len(data['B']['X2']))

# Compare probabilities
if likelihood_A > likelihood_B:
    prediction = 'A'
else:
    prediction = 'B'

print(f"The Naive Bayes classifier predicts that the new instance belongs to Class {prediction}.")
# Out:
# The Naive Bayes classifier predicts that the new instance belongs to Class A.
